# %% [markdown]
# # Exercise 2.1 : Intrinsic Evaluation
#
# ## Acknowledgement
#
# This notebook contains components of a notebook created by Pia Sommerauer.
# The original notebook (with more slides and examples, including code to create word embeddings) can be found here:
#
# https://github.com/PiaSommerauer/distributional_semantics
#
# ## Introduction
#
# This notebook walks you through Exercise 2.1 of Assignment 2. The goal of this exercise is to (1) get hands on experience in comparing word embeddings, and (2) carry out an intrinsic evaluation and reflect on it.
#
# The notebook illustrates:
#
# * how to load a distributional semantic model in Python (with indications of where to obtain such models)
# * how to calculate distances between vectors
# * how to create a ranking between vector pairs based on distances and compare this to a gold ranking

# %%
# We will be using gensim: https://pypi.org/project/gensim/
# It provides implementations of various forms of language modeling
# including functions to create and work with word embeddings

# You can install gensim by running `pip install gensim' on your commandline 
# You can run this from the notebook by uncommenting the line below:
# %pip install gensim

# Other packages you may want to install if you do not have them installed already
# %pip install pandas
# %pip install scipy


# You will only need to install each module once, so if you end up running this notebook multiple times,
# you'll want to skip this cell or comment the packages you have installed out again.

# %%
import gensim
# for loading a stored model 
from gensim.models import KeyedVectors

# pandas is a useful package for dealing with data structures
import pandas as pd
import numpy as np

# %% [markdown]
# ## Downloading a distributional semantic model
#
# There are many high quality distributional semantic models available. They are created from large corpora and have large coverage. Creating such models requires a lot of data and computation, and the more data, the better the model.
# You are therefore generally best of using one of these pretrained models.
#
# Sommerauer's notebook walks you through creating your own models (https://github.com/PiaSommerauer/distributional_semantics)
#
# For the exercises for this component, we will use existing models.
#
# ***Note though: these models are big!***
#
# The Google word embeddings created using word2vec can be found here (which we are using in the examples):
#
# https://code.google.com/archive/p/word2vec/
#
# Glove also has embeddings which take up a bit less space:
#
# https://nlp.stanford.edu/projects/glove/
#
# Note though, that you may have to apply a small conversion procedure before the gensim code works with glove embeddings (they are formatted slightly differently from the output of word2vec).
#
# It is explained here: https://radimrehurek.com/gensim/scripts/glove2word2vec.html

# %%
#loading a stored model. 

# Please make sure that the path `../models/GoogleNews-vectors-negative300.bin.gz' points to the location where you stored your word embeddings 
# if you are using a non-binary model, you will need to change binary=True to binary=False
ds_model = KeyedVectors.load_word2vec_format('/Users/hernando/Desktop/NLP/Assignment2/NLP_tech_distributional_semantics/models/GoogleNews-vectors-negative300.bin.gz'
                                             , binary=True)

# a first test with the model (you can replace "student" by other words)
ds_model.most_similar("student")
# Out:
# [('students', 0.7294867038726807),
#  ('Student', 0.6706663370132446),
#  ('teacher', 0.6301366090774536),
#  ('stu_dent', 0.6240992546081543),
#  ('faculty', 0.6087332963943481),
#  ('school', 0.6055628061294556),
#  ('undergraduate', 0.6020306348800659),
#  ('university', 0.6005399823188782),
#  ('undergraduates', 0.5755698680877686),
#  ('semester', 0.573759913444519)]

# %%
ds_model.most_similar("cry")
# Out:
# [('crying', 0.6610245704650879),
#  ('cries', 0.6551704406738281),
#  ('weep', 0.5748156309127808),
#  ('scream', 0.5718929767608643),
#  ('bawling', 0.5450262427330017),
#  ('sob', 0.5303637385368347),
#  ('cried', 0.5280172228813171),
#  ('sisters_nieces_nephews', 0.5045138597488403),
#  ('bawl', 0.5011399388313293),
#  ('yell', 0.5009252429008484)]

# %%
# similarity: a small scale experiment. Feel free to play with this and replace the terms

cos_man_woman = ds_model.similarity('man', 'woman')
cos_man_dog = ds_model.similarity('man', 'dog')


print(f'Man and woman should be more similar than man and dog:')
if cos_man_woman > cos_man_dog:
    print('True!')
    print('man-woman', cos_man_woman)
    print('man-dog', cos_man_dog)
else:
    print('False')
    print('man-woman', cos_man_woman)
    print('man-dog', cos_man_dog)
# Out:
# Man and woman should be more similar than man and dog:
# True!
# man-woman 0.76640123
# man-dog 0.3088647

# %%
simlex_data = pd.read_csv('/Users/hernando/Desktop/NLP/Assignment2/NLP_tech_distributional_semantics/SimLex-999/SimLex-999.txt',sep='\t')

# %%
simlex_data
# Out:
#            word1        word2 POS  SimLex999  conc(w1)  conc(w2)  concQ  \
# 0            old          new   A       1.58      2.72      2.81      2
# 1          smart  intelligent   A       9.20      1.75      2.46      1
# 2           hard    difficult   A       8.77      3.76      2.21      2
# 3          happy     cheerful   A       9.55      2.56      2.34      1
# 4           hard         easy   A       0.95      3.76      2.07      2
# 5           fast        rapid   A       8.75      3.32      3.07      2
# 6          happy         glad   A       9.17      2.56      2.36      1
# 7          short         long   A       1.23      3.61      3.18      2
# 8         stupid         dumb   A       9.58      1.75      2.36      1
# 9          weird      strange   A       8.93      1.59      1.86      1
# 10          wide       narrow   A       1.03      3.06      3.04      2
# 11           bad        awful   A       8.42      1.68      1.92      1
# 12          easy    difficult   A       0.58      2.07      2.21      1
# 13           bad     terrible   A       7.78      1.68      2.04      1
# 14          hard       simple   A       1.38      3.76      1.62      2
# 15         smart         dumb   A       0.55      1.75      2.36      1
# 16        insane        crazy   A       9.57      1.77      2.37      1
# 17         happy          mad   A       0.95      2.56      2.76      2
# 18         large         huge   A       9.47      3.37      3.54      2
# 19          hard        tough   A       8.05      3.76      2.50      2
# 20           new        fresh   A       6.83      2.81      1.97      1
# 21         sharp         dull   A       0.60      3.86      2.37      2
# 22         quick        rapid   A       9.70      2.89      3.07      2
# 23          dumb      foolish   A       6.67      2.36      1.84      1
# 24     wonderful     terrific   A       8.63      1.82      2.07      1
# 25       strange          odd   A       9.02      1.86      1.70      1
# 26         happy        angry   A       1.28      2.56      2.53      1
# 27        narrow        broad   A       1.18      3.04      2.45      2
# 28        simple         easy   A       9.40      1.62      2.07      1
# 29           old        fresh   A       0.87      2.72      1.97      1
# ..           ...          ...  ..        ...       ...       ...    ...
# 969         join          add   V       8.10      2.86      3.00      2
# 970         join        marry   V       5.35      2.86      3.03      2
# 971       accept      deliver   V       1.58      3.03      3.12      2
# 972       attach         join   V       7.75      3.33      2.86      2
# 973          put         hang   V       3.00      2.50      3.70      2
# 974           go         sell   V       0.97      3.15      3.35      2
# 975  communicate         pray   V       3.55      3.43      3.21      2
# 976         give        steal   V       0.50      2.83      3.84      2
# 977          add        build   V       4.92      3.00      3.71      2
# 978        bring      restore   V       2.62      2.55      2.79      2
# 979   comprehend      satisfy   V       2.55      1.86      2.04      1
# 980      portray       decide   V       1.18      2.18      1.92      1
# 981     organize       become   V       1.77      2.72      1.54      1
# 982         give         know   V       0.88      2.83      1.68      1
# 983          say       verify   V       4.90      2.58      2.10      1
# 984    cooperate         join   V       5.18      1.87      2.86      1
# 985      arrange      require   V       0.98      2.79      2.07      1
# 986       borrow         want   V       1.77      3.10      1.93      1
# 987  investigate       pursue   V       7.15      2.27      2.83      1
# 988       ignore      explore   V       0.40      2.22      2.90      1
# 989        bring     complain   V       0.98      2.55      2.60      1
# 990        enter          owe   V       0.68      3.12      2.07      1
# 991      portray       notify   V       0.78      2.18      3.04      2
# 992       remind         sell   V       0.40      2.19      3.35      2
# 993       absorb      possess   V       5.00      3.11      2.60      2
# 994         join      acquire   V       2.85      2.86      2.93      2
# 995         send       attend   V       1.67      2.70      3.17      2
# 996       gather       attend   V       4.80      2.75      3.17      2
# 997       absorb     withdraw   V       2.97      3.11      3.04      2
# 998       attend       arrive   V       6.08      3.17      3.22      2
#
#      Assoc(USF)  SimAssoc333  SD(SimLex)
# 0          7.25            1        0.41
# 1          7.11            1        0.67
# 2          5.94            1        1.19
# 3          5.85            1        2.18
# 4          5.82            1        0.93
# 5          5.66            1        1.68
# 6          5.49            1        1.59
# 7          5.36            1        1.58
# 8          5.26            1        1.48
# 9          4.26            1        1.30
# 10         4.06            1        0.58
# 11         3.41            1        1.74
# 12         2.83            1        0.36
# 13         2.31            1        1.43
# 14         2.16            1        1.03
# 15         2.10            1        0.47
# 16         2.09            1        0.92
# 17         2.07            1        1.40
# 18         2.00            1        1.27
# 19         1.99            1        1.18
# 20         1.98            1        1.20
# 21         1.48            1        1.39
# 22         1.38            1        1.14
# 23         1.34            1        1.36
# 24         1.17            1        1.63
# 25         1.16            1        1.04
# 26         1.15            1        1.41
# 27         1.00            1        1.18
# 28         0.96            1        1.51
# 29         0.91            1        1.64
# ..          ...          ...         ...
# 969        0.11            0        0.88
# 970        0.11            0        1.41
# 971        0.11            0        1.37
# 972        0.11            0        0.94
# 973        0.11            0        1.49
# 974        0.11            0        0.90
# 975        0.11            0        1.38
# 976        0.11            0        0.62
# 977        0.11            0        1.10
# 978        0.10            0        0.74
# 979        0.00            0        1.00
# 980        0.00            0        1.37
# 981        0.00            0        1.86
# 982        0.00            0        1.12
# 983        0.00            0        0.65
# 984        0.00            0        0.36
# 985        0.00            0        1.72
# 986        0.00            0        1.22
# 987        0.00            0        0.56
# 988        0.00            0        1.19
# 989        0.00            0        1.57
# 990        0.00            0        1.67
# 991        0.00            0        1.17
# 992        0.00            0        1.61
# 993        0.00            0        1.15
# 994        0.00            0        0.99
# 995        0.00            0        1.44
# 996        0.00            0        1.97
# 997        0.00            0        1.75
# 998        0.00            0        1.18
#
# [999 rows x 10 columns]

# %%
ds_scores = {}
huma_scores = {}
human_scores = []
model_scores = []
k=1
for index, row in simlex_data.sort_values(by='SimLex999', ascending=False).iterrows():
    wordpair = row['word1'] + '-' + row['word2']
    human_scores.append(row['SimLex999'])
    ds_score = ds_model.similarity(row['word1'],row['word2'])
    model_scores.append(ds_score)
    ds_scores[wordpair] = ds_model.similarity(row['word1'],row['word2'])
    huma_scores[wordpair] = k
    k+=1

    
### Also saving the ranked output by the model to a file for inspection
ds_ranked_output = open('/Users/hernando/Desktop/NLP/Assignment2/NLP_tech_distributional_semantics/SimLex-999/ds_output_simlex_pairs.txt', 'w')
for index, word_pair in enumerate(sorted(ds_scores, key=ds_scores.get, reverse=True)):
    ds_ranked_output.write(str(index) + '\t' + word_pair + '\t' + str(ds_scores[word_pair]) + '\n')

# %%
#calculate spearman rho

from scipy.stats import spearmanr

spearmanr(human_scores, model_scores)
# Out:
# SpearmanrResult(correlation=0.44196551091403796, pvalue=5.068221892023142e-49)

# %%
model_scores
# Out:
# [0.9004227,
#  0.49779078,
#  0.26050574,
#  0.81731385,
#  0.73390424,
#  0.5561479,
#  0.38377383,
#  0.6319464,
#  0.568542,
#  0.6589166,
#  0.59902996,
#  0.73785883,
#  0.512326,
#  0.8204511,
#  0.6608624,
#  0.32185915,
#  0.6716382,
#  0.52532834,
#  0.6495278,
#  0.75105584,
#  0.6381518,
#  0.69855225,
#  0.32383794,
#  0.74088913,
#  0.60004014,
#  0.51001453,
#  0.39905614,
#  0.38605824,
#  0.33244228,
#  0.5692449,
#  0.7366201,
#  0.41570213,
#  0.51920044,
#  0.7307427,
#  0.8288328,
#  0.48149034,
#  0.6254826,
#  0.8164579,
#  0.61649424,
#  0.7806021,
#  0.6101885,
#  0.38535285,
#  0.867677,
#  0.6705386,
#  0.5083667,
#  0.20618345,
#  0.34495902,
#  0.7076315,
#  0.52110577,
#  0.6972494,
#  0.70388985,
#  0.6025748,
#  0.5661683,
#  0.4766829,
#  0.2910281,
#  0.73593664,
#  0.6248339,
#  0.57660407,
#  0.4441522,
#  0.7009895,
#  0.4846029,
#  0.6574996,
#  0.47935694,
#  0.34695202,
#  0.31333324,
#  0.7420832,
#  0.46401468,
#  0.7061798,
#  0.10783214,
#  0.3124522,
#  0.38943344,
#  0.5354876,
#  0.4997485,
#  0.54384553,
#  0.5695981,
#  0.47361746,
#  0.70720327,
#  0.33942583,
#  0.6539289,
#  0.5527253,
#  0.66219604,
#  0.6327857,
#  0.5617907,
#  0.5455808,
#  0.68963295,
#  0.26239014,
#  0.4300737,
#  0.5967071,
#  0.76430905,
#  0.47928116,
#  0.17311642,
#  0.5926057,
#  0.76435417,
#  0.20255296,
#  0.6733354,
#  0.15195268,
#  0.44788152,
#  0.36278558,
#  0.5337858,
#  0.58068454,
#  0.5386841,
#  0.64870703,
#  0.40758595,
#  0.29770327,
#  0.33020693,
#  0.7661097,
#  0.6976641,
#  0.5992341,
#  0.2711504,
#  0.15570384,
#  0.52797955,
#  0.29680532,
#  0.27525103,
#  0.7647869,
#  0.6342882,
#  0.7479892,
#  0.32780182,
#  0.5131841,
#  0.42000252,
#  0.40531805,
#  0.42230085,
#  0.75096357,
#  0.32155755,
#  0.4790024,
#  0.34874788,
#  0.2558066,
#  0.51592994,
#  0.42775473,
#  0.29903537,
#  0.51978606,
#  0.3058018,
#  0.3788017,
#  0.5903207,
#  0.41143158,
#  0.4524265,
#  0.4651036,
#  0.68286115,
#  0.3321272,
#  0.13634898,
#  0.48466656,
#  0.4302186,
#  0.5641326,
#  0.6274098,
#  0.43190464,
#  0.40882897,
#  0.41087896,
#  0.36704215,
#  0.16465066,
#  0.34194678,
#  0.43101165,
#  0.21251278,
#  0.47543713,
#  0.3551134,
#  0.5327611,
#  0.46076736,
#  0.2617682,
#  0.40812337,
#  0.46340537,
#  0.347332,
#  0.32526675,
#  0.37592423,
#  0.5099495,
#  0.4706288,
#  0.7393565,
#  0.46570224,
#  0.66666037,
#  0.4602587,
#  0.47345287,
#  0.6322844,
#  0.69180346,
#  0.38287073,
#  0.2562204,
#  0.5724613,
#  0.49053514,
#  0.47469556,
#  0.26879394,
#  0.7018068,
#  0.21541715,
#  0.34831122,
#  0.35430163,
#  0.5369112,
#  0.2733534,
#  0.411493,
#  0.42739883,
#  0.42392495,
#  0.580571,
#  0.40497932,
#  0.24124043,
#  0.37430397,
#  0.43550134,
#  0.32577744,
#  0.21950349,
#  0.24295107,
#  0.17029774,
#  0.14984529,
#  0.3526737,
#  0.25611827,
#  0.2469697,
#  0.5969481,
#  0.63757634,
#  0.3378835,
#  0.5727046,
#  0.47309354,
#  0.28390557,
#  0.24356294,
#  0.62270415,
#  0.6843625,
#  0.40061745,
#  0.31771705,
#  0.67682433,
#  0.41505015,
#  0.19230641,
#  0.793001,
#  0.24656315,
#  0.37681934,
#  0.4518231,
#  0.50313216,
#  0.10109154,
#  0.1582865,
#  0.2569027,
#  0.6765697,
#  0.15495692,
#  0.8357889,
#  0.44826445,
#  0.19198282,
#  0.5763146,
#  0.40286672,
#  0.47691193,
#  0.4992186,
#  0.3313637,
#  0.39992446,
#  0.5026151,
#  0.6137953,
#  0.50683904,
#  0.56891793,
#  0.3907522,
#  0.42109329,
#  0.3128757,
#  0.5503442,
#  0.3882374,
#  0.5750503,
#  0.44456038,
#  0.30210155,
#  0.3997731,
#  0.43003535,
#  0.41977185,
#  0.296156,
#  0.33817706,
#  0.18287943,
#  0.6337764,
#  0.5930409,
#  0.30149722,
#  0.20230791,
#  0.44572586,
#  0.6149927,
#  0.6945997,
#  0.31494355,
#  0.17189401,
#  0.42500284,
#  0.4329391,
#  0.2637192,
#  0.51953924,
#  0.40895706,
#  0.450409,
#  0.5290361,
#  0.45284832,
#  0.49614778,
#  0.40193012,
#  0.44068,
#  0.42470035,
#  0.7355941,
#  0.43275455,
#  0.39820108,
#  0.68540865,
#  0.24798267,
#  0.45968777,
#  0.3109468,
#  0.4035171,
#  0.3523432,
#  0.5360568,
#  0.4417468,
#  0.5964688,
#  0.46522433,
#  0.7321894,
#  0.40270835,
#  0.48090208,
#  0.268535,
#  0.28384086,
#  0.206609,
#  0.31476963,
#  0.44017124,
#  0.3158933,
#  0.49649072,
#  0.25199145,
#  0.6334267,
#  0.619251,
#  0.36687228,
#  0.4119911,
#  0.47219107,
#  0.27358446,
#  0.2783013,
#  0.33554468,
#  0.45811045,
#  0.34096608,
#  0.25938243,
#  0.52446306,
#  0.23610136,
#  0.42482007,
#  0.44178507,
#  0.43801796,
#  0.27825424,
#  0.4920994,
#  0.28118017,
#  0.36538497,
#  0.42677706,
#  0.30920893,
#  0.5376728,
#  0.20313716,
#  0.38924685,
#  0.2883889,
#  0.5628653,
#  0.6138772,
#  0.54369783,
#  0.42107168,
#  0.31437707,
#  0.4443887,
#  0.48825437,
#  0.39694604,
#  0.3189662,
#  0.31562647,
#  0.6891531,
#  0.61599934,
#  0.3968417,
#  0.1787059,
#  0.5964593,
#  0.35270208,
#  0.3549483,
#  0.26516953,
#  0.415512,
#  0.39794374,
#  0.5024792,
#  0.37791824,
#  0.29126722,
#  0.25766706,
#  0.6628997,
#  0.49832982,
#  0.35842544,
#  0.5192578,
#  0.41068262,
#  0.49563688,
#  0.39171845,
#  0.5115951,
#  0.40750363,
#  0.5927852,
#  0.37248808,
#  0.47745338,
#  0.509803,
#  0.444824,
#  0.25756857,
#  0.31900755,
#  0.34382758,
#  0.39597487,
#  0.38339078,
#  0.081278965,
#  0.3450359,
#  0.4963317,
#  0.50944805,
#  0.33485338,
#  0.50713223,
#  0.1369897,
#  0.22401835,
#  0.57235533,
#  0.25264245,
#  0.32715023,
#  0.52942437,
#  0.36614382,
#  0.39896992,
#  0.22408682,
#  0.13267297,
#  0.37405685,
#  0.58855635,
#  0.7643474,
#  0.5438281,
#  0.19487195,
#  0.6777031,
#  0.5175463,
#  0.38798764,
#  0.30058756,
#  0.6081667,
#  0.4613854,
#  0.3310857,
#  0.2556744,
#  0.24534461,
#  0.19426128,
#  0.36976275,
#  0.58702266,
#  0.43375057,
#  0.58055335,
#  0.4130412,
#  0.5545867,
#  0.5892083,
#  0.47715586,
#  0.3212616,
#  0.35487777,
#  0.48207593,
#  0.42891365,
#  0.17074767,
#  0.32295853,
#  0.52962136,
#  0.44123206,
#  0.34499747,
#  0.51828825,
#  0.3694909,
#  0.35498416,
#  0.49684715,
#  0.48107952,
#  0.24227078,
#  0.20762011,
#  0.25941545,
#  0.44731447,
#  0.39373493,
#  0.4863198,
#  0.4936767,
#  0.31202433,
#  0.09880819,
#  0.6008035,
#  0.25710192,
#  0.4673912,
#  0.50616634,
#  0.44797096,
#  0.26711252,
#  0.3698433,
#  0.24922553,
#  0.33785418,
#  0.27680513,
#  0.35109073,
#  0.32932594,
#  0.21549077,
#  0.27307,
#  0.26075995,
#  0.5014468,
#  0.3340648,
#  0.43867612,
#  0.291271,
#  0.5261595,
#  0.23864424,
#  0.11445659,
#  0.5187395,
#  0.12855084,
#  0.13239557,
#  0.57262594,
#  0.41698116,
#  0.45148632,
#  0.283111,
#  0.29275313,
#  0.2564185,
#  0.35100657,
#  0.3695038,
#  0.39501724,
#  0.641185,
#  0.42206135,
#  0.48088345,
#  0.43186063,
#  0.42658657,
#  0.2863422,
#  0.19868994,
#  0.6069665,
#  0.2959686,
#  0.23302923,
#  0.52599543,
#  0.3866138,
#  0.19325425,
#  0.33474168,
#  0.4201101,
#  0.5282956,
#  0.1374209,
#  0.5308864,
#  0.33290234,
#  0.46675012,
#  0.30265594,
#  0.49791452,
#  0.22534375,
#  -0.009103347,
#  0.69721293,
#  0.2886822,
#  0.40438113,
#  0.11980726,
#  0.45337975,
#  0.2570263,
#  0.52955425,
#  0.31516853,
#  0.27344376,
#  0.4054544,
#  0.40316445,
#  0.40547103,
#  0.435135,
#  0.30387095,
#  0.39678967,
#  0.43353316,
#  0.3852697,
#  0.21336083,
#  0.7791938,
#  0.25740638,
#  0.20464996,
#  0.36569855,
#  0.5677171,
#  0.46009266,
#  0.2895971,
#  0.45975837,
#  0.24479692,
#  0.3357208,
#  0.073452406,
#  0.48453102,
#  0.43770254,
#  0.37851626,
#  0.14024927,
#  0.453841,
#  0.65370506,
#  0.43384025,
#  0.22928682,
#  0.28173226,
#  0.36706927,
#  0.4770291,
#  0.54807967,
#  0.32154286,
#  0.5182057,
#  0.3044642,
#  0.35960886,
#  0.48194847,
#  0.24271116,
#  0.29247743,
#  0.21530917,
#  0.56670415,
#  0.8240807,
#  0.2792005,
#  0.21427728,
#  0.23830943,
#  0.443998,
#  0.22718483,
#  0.33646762,
#  0.37564188,
#  0.534333,
#  0.40437287,
#  0.2812734,
#  0.22300832,
#  0.228281,
#  0.31633338,
#  0.3301253,
#  0.3088184,
#  0.30241483,
#  0.3009936,
#  0.3339854,
#  0.48292348,
#  0.51521695,
#  0.22197892,
#  0.26040843,
#  0.4434315,
#  0.35563985,
#  0.7129932,
#  0.18057771,
#  0.18860735,
#  0.30050603,
#  0.39817473,
#  0.50522584,
#  0.08469795,
#  0.3267405,
#  0.38456932,
#  0.453805,
#  0.17662707,
#  0.4186319,
#  0.42429638,
#  0.4437555,
#  0.369711,
#  0.39190325,
#  0.4265793,
#  0.33685392,
#  0.8933086,
#  0.26859778,
#  0.13564357,
#  0.40843445,
#  0.22506985,
#  0.4574151,
#  0.40305296,
#  0.26208335,
#  0.51769304,
#  0.45857143,
#  0.5056747,
#  0.3959363,
#  0.41789657,
#  0.5359422,
#  0.13199839,
#  0.5034812,
#  0.4020973,
#  0.41340244,
#  0.39878458,
#  0.45672265,
#  0.38895652,
#  0.4501871,
#  0.5316955,
#  0.10333385,
#  0.56242114,
#  0.4662387,
#  0.49793482,
#  0.65518534,
#  0.06772888,
#  0.18720008,
#  0.29051793,
#  0.9415395,
#  0.100222856,
#  0.23294652,
#  0.29471982,
#  0.35809785,
#  0.503168,
#  0.123897344,
#  0.40245304,
#  0.3143264,
#  0.30487147,
#  0.66088724,
#  0.20831698,
#  0.23098704,
#  0.2333686,
#  0.1831049,
#  0.3444939,
#  0.6030655,
#  0.16453455,
#  0.83795327,
#  0.5364484,
#  0.10848026,
#  0.59521013,
#  0.51273733,
#  0.25495356,
#  0.26202923,
#  0.2888331,
#  0.33873087,
#  0.61749756,
#  0.49875164,
#  0.52464,
#  0.36440864,
#  0.61521256,
#  0.33202934,
#  0.76640123,
#  0.4785698,
#  0.5006557,
#  0.62127966,
#  0.44194803,
#  0.30235267,
#  0.7007028,
#  0.16838762,
#  0.2517231,
#  0.4177304,
#  0.5161999,
#  0.19597802,
#  0.24395967,
#  0.25781795,
#  0.14514193,
#  0.20070933,
#  0.30184454,
#  0.675821,
#  0.24632351,
#  0.29459968,
#  0.70869863,
#  0.2718235,
#  0.15458119,
#  0.16245875,
#  0.34797814,
#  0.16253494,
#  0.65569407,
#  0.6531843,
#  0.4414632,
#  0.24085274,
#  0.5128528,
#  0.0388651,
#  0.25265613,
#  0.440956,
#  0.17448711,
#  0.4087127,
#  0.7550682,
#  0.2380485,
#  0.3996979,
#  0.49417195,
#  0.49109736,
#  0.14900799,
#  0.4675454,
#  0.14120878,
#  0.3058267,
#  0.48253256,
#  0.21690394,
#  0.5191699,
#  0.32115218,
#  0.6359612,
#  0.45652422,
#  0.19806895,
#  0.55055463,
#  0.22921266,
#  0.4474556,
#  0.26234367,
#  0.2623194,
#  0.36362627,
#  0.5243437,
#  0.5164587,
#  0.28246734,
#  0.49015146,
#  0.26532164,
#  0.3051032,
#  0.20023346,
#  0.38825035,
#  0.56184316,
#  0.6386003,
#  0.36441755,
#  0.33398485,
#  0.43668535,
#  0.22419804,
#  0.10199315,
#  0.29566726,
#  0.3293295,
#  0.3362847,
#  0.3790637,
#  0.21996221,
#  0.3950398,
#  0.73749715,
#  0.42664862,
#  0.28477663,
#  0.2244373,
#  0.255549,
#  0.13867329,
#  0.14749959,
#  0.33248457,
#  0.15437351,
#  0.3025503,
#  0.33395496,
#  0.46549425,
#  0.10723545,
#  0.54434234,
#  0.3919184,
#  0.10128181,
#  0.4296493,
#  0.30319738,
#  0.6612358,
#  0.2175189,
#  0.10432802,
#  0.19960001,
#  0.6604678,
#  0.62556756,
#  0.19100173,
#  0.48258072,
#  0.27660328,
#  0.3314124,
#  0.41226977,
#  0.7155519,
#  0.58780026,
#  0.6261382,
#  0.42365703,
#  0.42731142,
#  0.48715863,
#  0.15728584,
#  0.11924468,
#  0.07570742,
#  0.28292993,
#  0.21976632,
#  0.16406733,
#  0.08494117,
#  0.06727685,
#  0.8294167,
#  0.4060359,
#  0.4462179,
#  0.21306144,
#  0.17387623,
#  0.21991491,
#  0.2511613,
#  0.17473215,
#  0.96745354,
#  0.13577297,
#  0.44217682,
#  0.04097097,
#  0.26532018,
#  0.40531346,
#  0.26933104,
#  0.20630302,
#  0.27603593,
#  0.47253582,
#  0.20332582,
#  0.48303565,
#  0.0904883,
#  0.46231908,
#  0.1672957,
#  0.3038275,
#  0.27603593,
#  0.070434324,
#  0.54040307,
#  0.4206618,
#  0.04493615,
#  -0.0413233,
#  0.27251133,
#  0.12951373,
#  0.22081567,
#  0.15227032,
#  0.41650054,
#  0.50700074,
#  0.037674516,
#  0.4701502,
#  0.17344761,
#  0.16126499,
#  -0.0022380736,
#  0.76094574,
#  0.29796585,
#  0.4426736,
#  0.40460178,
#  0.43876112,
#  0.4208318,
#  0.37743762,
#  0.29206952,
#  0.31350026,
#  0.4385648,
#  0.3862585,
#  0.24939163,
#  0.51056665,
#  0.23467252,
#  0.37679264,
#  0.21364546,
#  0.3119375,
#  0.32685998,
#  0.31100902,
#  0.2428882,
#  0.5181179,
#  0.30034435,
#  0.22278027,
#  0.47235405,
#  0.06980878,
#  0.62043184,
#  0.15880981,
#  0.15922289,
#  0.51351184,
#  0.33356753,
#  0.2182361,
#  0.34863457,
#  0.36306632,
#  0.2910601,
#  0.46946314,
#  0.26720995,
#  0.35848734,
#  0.2743814,
#  0.44684848,
#  0.25914517,
#  0.32353783,
#  0.46789753,
#  0.15596089,
#  0.19453354,
#  0.39859158,
#  0.22043686,
#  0.30461404,
#  0.3749322,
#  0.3359697,
#  0.16624789,
#  0.16635905,
#  0.57684326,
#  0.114824064,
#  0.32772133,
#  0.4094437,
#  0.387555,
#  0.15872651,
#  0.20913137,
#  0.45757687,
#  0.091678955,
#  0.12956238,
#  0.4325047,
#  0.28854597,
#  0.47599494,
#  0.36050647,
#  0.42763603,
#  0.17905192,
#  0.08229521,
#  0.46566275,
#  0.30177683,
#  0.3051433,
#  0.00028206612,
#  0.05344815,
#  0.46330068,
#  0.2909014,
#  0.30899587,
#  0.30240107,
#  0.3781266,
#  0.34025368,
#  0.33836463,
#  0.2077549,
#  0.33188802,
#  0.45760992,
#  0.17092839,
#  0.15107246,
#  0.06950563,
#  0.03302442,
#  0.22479127,
#  0.2003135,
#  0.27502218,
#  0.19423172,
#  0.26873162,
#  0.48797837,
#  0.2190395,
#  0.39202872,
#  0.47096327,
#  0.47641212,
#  0.5859931,
#  0.44993773,
#  0.32852787,
#  0.0957245,
#  0.30868515,
#  0.18692225,
#  0.14221619,
#  0.30571076,
#  0.5562858,
#  0.27726495,
#  0.34452328,
#  0.66923505,
#  0.1455334,
#  -0.013140774,
#  0.44142058,
#  0.24782847,
#  0.5025952,
#  0.40794012,
#  0.4891661,
#  0.27713364,
#  0.45982468,
#  0.101861924,
#  0.15111299,
#  0.21765324,
#  0.042105,
#  0.05885411,
#  0.00040805995,
#  0.029547798,
#  0.08341231,
#  0.03530624,
#  0.047245093,
#  0.16044317,
#  0.38109574,
#  0.42774177,
#  0.3772241,
#  0.15699297,
#  0.37621212,
#  0.30036443,
#  0.16194978,
#  0.17448705,
#  0.07392339,
#  0.0790726,
#  0.1804049,
#  0.5890915,
#  0.11419436,
#  0.5792695,
#  0.38044342,
#  0.43044716,
#  0.45547155,
#  0.32030508,
#  0.05288793,
#  0.1701994,
#  0.04098731,
#  -0.017754188,
#  0.04892069,
#  0.1320168,
#  0.08071669,
#  0.09499871,
#  0.0011825244,
#  0.04893481,
#  0.19201459,
#  0.039968748,
#  0.15440772,
#  0.1262145,
#  0.1927982,
#  0.04115732,
#  0.23213239,
#  0.16726783,
#  0.04972478,
#  0.11618938,
#  0.21225451,
#  0.109042175,
#  0.09536491,
#  0.1480109,
#  0.13166961,
#  0.1759281,
#  0.0595204,
#  0.15273158,
#  0.27059802,
#  0.36420557,
#  0.05187906,
#  0.026498515,
#  -0.036866095,
#  0.25442204,
#  0.1578645,
#  0.15692365,
#  0.042893145,
#  0.3928765,
#  0.16252668,
#  0.048501704,
#  0.12584047,
#  0.17320642,
#  0.00039425644,
#  0.03541921,
#  0.13876101,
#  0.10117235,
#  0.11327725,
#  0.16565862,
#  0.57072806]

# %%
computer_rank = pd.read_csv('/Users/hernando/Desktop/NLP/Assignment2/NLP_tech_distributional_semantics/SimLex-999/ds_output_simlex_pairs.txt', sep='\t', header=None)
human_rank = pd.read_csv('/Users/hernando/Desktop/NLP/Assignment2/NLP_tech_distributional_semantics/SimLex-999.ordered.pairs.csv', sep='\t', header=None)
human_rank.columns=['rank','word','score']
computer_rank.columns=['rank','word','score']
# computer_rank['score']=computer_rank['score'].apply(lambda x : round(x,2))

# %%
set_1={}
for i in range(len(computer_rank)):
    set_1[computer_rank['word'].values[i]]= huma_scores[computer_rank['word'].values[i]]-(i+1)

# %%
sorted(set_1.items(), key=lambda d: d[1])
# Out:
# [('acquire-get', -773),
#  ('keep-possess', -768),
#  ('think-rationalize', -729),
#  ('creator-maker', -724),
#  ('satisfy-please', -723),
#  ('reflection-image', -669),
#  ('value-belief', -664),
#  ('polite-proper', -660),
#  ('make-construct', -634),
#  ('crowd-bunch', -627),
#  ('crime-violation', -626),
#  ('attention-awareness', -616),
#  ('money-salary', -616),
#  ('recent-new', -615),
#  ('god-spirit', -606),
#  ('chair-bench', -602),
#  ('come-attend', -598),
#  ('appointment-engagement', -597),
#  ('hallway-corridor', -586),
#  ('log-timber', -585),
#  ('proof-fact', -579),
#  ('scarce-rare', -576),
#  ('big-broad', -571),
#  ('wood-log', -570),
#  ('rabbi-minister', -569),
#  ('wisdom-intelligence', -568),
#  ('administration-management', -558),
#  ('take-possess', -557),
#  ('alcohol-gin', -555),
#  ('mood-emotion', -554),
#  ('crib-cradle', -552),
#  ('cop-sheriff', -551),
#  ('exotic-rare', -547),
#  ('leader-manager', -544),
#  ('take-obtain', -543),
#  ('communication-language', -534),
#  ('aisle-hall', -528),
#  ('mob-crowd', -527),
#  ('politician-president', -521),
#  ('father-parent', -518),
#  ('hard-dense', -516),
#  ('contemplate-think', -505),
#  ('code-symbol', -504),
#  ('win-accomplish', -501),
#  ('buddy-companion', -485),
#  ('happy-cheerful', -483),
#  ('join-add', -482),
#  ('certain-sure', -481),
#  ('cancer-sickness', -480),
#  ('intelligence-logic', -479),
#  ('battle-conquest', -477),
#  ('communication-conversation', -475),
#  ('noise-rattle', -465),
#  ('boundary-border', -458),
#  ('money-capital', -458),
#  ('appear-attend', -455),
#  ('intelligence-skill', -455),
#  ('exit-doorway', -448),
#  ('task-job', -445),
#  ('conclude-decide', -443),
#  ('engage-marry', -440),
#  ('bad-immoral', -438),
#  ('declare-announce', -429),
#  ('proclaim-announce', -429),
#  ('acquire-find', -426),
#  ('take-steal', -425),
#  ('win-succeed', -419),
#  ('cloud-storm', -418),
#  ('idea-scheme', -413),
#  ('vitamin-iron', -410),
#  ('fever-illness', -407),
#  ('style-fashion', -406),
#  ('gather-meet', -406),
#  ('ray-sunshine', -404),
#  ('activity-movement', -401),
#  ('overcome-dominate', -401),
#  ('alcohol-cocktail', -398),
#  ('club-society', -398),
#  ('book-text', -394),
#  ('make-earn', -389),
#  ('dictionary-definition', -389),
#  ('goal-quest', -389),
#  ('corporation-business', -383),
#  ('vision-perception', -383),
#  ('charcoal-coal', -381),
#  ('depth-magnitude', -380),
#  ('intelligence-insight', -380),
#  ('bed-furniture', -375),
#  ('opinion-idea', -375),
#  ('bias-opinion', -375),
#  ('population-people', -370),
#  ('begin-go', -367),
#  ('opinion-choice', -366),
#  ('birthday-date', -366),
#  ('beast-animal', -364),
#  ('cherish-keep', -364),
#  ('cloud-weather', -363),
#  ('attention-interest', -362),
#  ('alcohol-wine', -358),
#  ('collect-save', -358),
#  ('pipe-cigar', -358),
#  ('alcohol-brandy', -355),
#  ('action-course', -351),
#  ('shelter-hut', -349),
#  ('plate-bowl', -349),
#  ('capability-competence', -344),
#  ('alcohol-whiskey', -344),
#  ('belly-abdomen', -330),
#  ('size-magnitude', -326),
#  ('guy-stud', -326),
#  ('absorb-possess', -323),
#  ('competence-ability', -321),
#  ('mouth-tooth', -320),
#  ('create-imagine', -320),
#  ('behave-obey', -319),
#  ('formal-proper', -318),
#  ('room-cell', -316),
#  ('accept-believe', -314),
#  ('wealth-prestige', -311),
#  ('rail-fence', -310),
#  ('argue-differ', -309),
#  ('doctor-professor', -308),
#  ('game-action', -306),
#  ('reject-avoid', -301),
#  ('area-zone', -295),
#  ('sunset-evening', -292),
#  ('create-make', -289),
#  ('author-creator', -289),
#  ('evening-dusk', -289),
#  ('mouth-lip', -287),
#  ('succeed-try', -287),
#  ('belief-concept', -286),
#  ('car-carriage', -284),
#  ('belief-opinion', -283),
#  ('army-legion', -283),
#  ('calf-bull', -283),
#  ('band-parade', -282),
#  ('bold-proud', -281),
#  ('formula-equation', -280),
#  ('belief-impression', -280),
#  ('sense-intuition', -278),
#  ('choose-elect', -274),
#  ('friend-guest', -274),
#  ('bad-guilty', -271),
#  ('argue-persuade', -268),
#  ('army-squad', -265),
#  ('absorb-learn', -264),
#  ('water-ice', -262),
#  ('argument-criticism', -259),
#  ('take-deliver', -259),
#  ('bird-hawk', -258),
#  ('river-stream', -253),
#  ('big-heavy', -253),
#  ('kill-hang', -250),
#  ('president-mayor', -248),
#  ('word-literature', -248),
#  ('seed-mustard', -247),
#  ('agree-please', -245),
#  ('investigate-pursue', -244),
#  ('quick-rapid', -243),
#  ('hand-foot', -243),
#  ('aviation-flight', -242),
#  ('acquire-obtain', -241),
#  ('ignore-avoid', -241),
#  ('cottage-cabin', -240),
#  ('adult-guardian', -240),
#  ('necessary-important', -239),
#  ('wealth-fame', -237),
#  ('telephone-booth', -237),
#  ('abundance-plenty', -235),
#  ('pollution-atmosphere', -235),
#  ('death-catastrophe', -235),
#  ('wagon-carriage', -233),
#  ('camp-cabin', -233),
#  ('second-minute', -232),
#  ('fast-rapid', -229),
#  ('know-comprehend', -229),
#  ('accident-emergency', -229),
#  ('story-topic', -224),
#  ('eye-tear', -223),
#  ('violent-angry', -222),
#  ('driver-pilot', -221),
#  ('pretend-portray', -220),
#  ('helper-maid', -220),
#  ('fail-discourage', -217),
#  ('cloud-haze', -214),
#  ('say-verify', -214),
#  ('motor-engine', -212),
#  ('pretend-imagine', -212),
#  ('confidence-self', -212),
#  ('cat-lion', -210),
#  ('listen-obey', -210),
#  ('journey-conquest', -210),
#  ('loop-belt', -208),
#  ('attend-arrive', -207),
#  ('fee-payment', -206),
#  ('lose-fail', -205),
#  ('student-pupil', -204),
#  ('friendly-generous', -203),
#  ('meter-yard', -203),
#  ('box-booth', -203),
#  ('assignment-task', -202),
#  ('pain-harm', -202),
#  ('accident-catastrophe', -199),
#  ('bible-hymn', -199),
#  ('elastic-flexible', -196),
#  ('day-dawn', -195),
#  ('idea-image', -195),
#  ('plead-beg', -194),
#  ('win-dominate', -194),
#  ('join-marry', -193),
#  ('understand-forgive', -193),
#  ('become-appear', -191),
#  ('mother-guardian', -187),
#  ('confident-sure', -186),
#  ('book-story', -185),
#  ('comfort-safety', -184),
#  ('save-protect', -183),
#  ('shore-coast', -179),
#  ('bed-crib', -179),
#  ('target-arrow', -179),
#  ('rod-curtain', -179),
#  ('teacher-instructor', -175),
#  ('accomplish-become', -172),
#  ('rat-mouse', -171),
#  ('pursue-persuade', -169),
#  ('business-company', -168),
#  ('aggression-hostility', -166),
#  ('limb-leg', -166),
#  ('ask-plead', -166),
#  ('god-priest', -166),
#  ('go-allow', -166),
#  ('teacher-rabbi', -165),
#  ('endurance-strength', -164),
#  ('aisle-hallway', -163),
#  ('guilty-ashamed', -163),
#  ('body-spine', -162),
#  ('happiness-peace', -159),
#  ('way-manner', -158),
#  ('nail-thumb', -158),
#  ('clothes-fabric', -157),
#  ('large-big', -155),
#  ('replace-restore', -155),
#  ('argue-rationalize', -154),
#  ('bottle-container', -153),
#  ('take-receive', -153),
#  ('communicate-pray', -153),
#  ('wire-cord', -151),
#  ('heroine-hero', -148),
#  ('achieve-succeed', -147),
#  ('machine-engine', -143),
#  ('college-class', -143),
#  ('area-region', -142),
#  ('sky-universe', -142),
#  ('man-husband', -140),
#  ('yard-inch', -139),
#  ('crime-theft', -138),
#  ('imitate-portray', -138),
#  ('word-page', -138),
#  ('cloud-mist', -136),
#  ('unhappy-mad', -135),
#  ('flower-bush', -135),
#  ('leave-go', -134),
#  ('brow-eye', -134),
#  ('parent-adult', -133),
#  ('book-literature', -132),
#  ('enjoy-entertain', -131),
#  ('nice-generous', -131),
#  ('get-buy', -130),
#  ('stomach-vein', -130),
#  ('tree-maple', -129),
#  ('crime-fraud', -128),
#  ('cabin-hut', -127),
#  ('death-tragedy', -124),
#  ('glass-crystal', -123),
#  ('man-warrior', -123),
#  ('emotion-passion', -122),
#  ('stomach-waist', -122),
#  ('car-factory', -122),
#  ('beer-alcohol', -121),
#  ('strength-capability', -121),
#  ('adversary-opponent', -119),
#  ('book-article', -117),
#  ('steeple-chapel', -116),
#  ('absorb-withdraw', -116),
#  ('discuss-explain', -114),
#  ('nail-hand', -114),
#  ('arrive-come', -113),
#  ('add-divide', -113),
#  ('linen-fabric', -112),
#  ('teacher-helper', -111),
#  ('simple-easy', -108),
#  ('man-sentry', -108),
#  ('noticeable-obvious', -107),
#  ('meter-inch', -106),
#  ('new-fresh', -104),
#  ('gun-cannon', -104),
#  ('marijuana-herb', -103),
#  ('acknowledge-notify', -102),
#  ('inspect-examine', -101),
#  ('bee-queen', -101),
#  ('gather-attend', -100),
#  ('verify-justify', -100),
#  ('chief-mayor', -99),
#  ('chemistry-theory', -99),
#  ('atom-carbon', -98),
#  ('fragile-frigid', -97),
#  ('reduce-shrink', -96),
#  ('explore-discover', -95),
#  ('discussion-argument', -95),
#  ('anger-mood', -94),
#  ('clothes-drawer', -93),
#  ('protect-defend', -92),
#  ('situation-condition', -92),
#  ('shoulder-head', -92),
#  ('song-story', -91),
#  ('sofa-chair', -90),
#  ('boat-anchor', -89),
#  ('greet-meet', -88),
#  ('give-lend', -87),
#  ('ceiling-cathedral', -87),
#  ('cow-cattle', -86),
#  ('gut-nerve', -86),
#  ('body-shoulder', -86),
#  ('circumstance-situation', -84),
#  ('bad-awful', -83),
#  ('purse-bag', -83),
#  ('bell-door', -83),
#  ('locate-find', -82),
#  ('harsh-cruel', -82),
#  ('realize-discover', -81),
#  ('remain-retain', -81),
#  ('fun-football', -81),
#  ('cloud-fog', -80),
#  ('floor-deck', -80),
#  ('easy-flexible', -80),
#  ('compare-analyze', -79),
#  ('think-decide', -79),
#  ('blood-flesh', -79),
#  ('winner-goal', -78),
#  ('laden-heavy', -77),
#  ('wall-decoration', -77),
#  ('couple-pair', -76),
#  ('flu-fever', -76),
#  ('deserve-earn', -76),
#  ('borrow-want', -76),
#  ('cooperate-participate', -75),
#  ('wagon-container', -75),
#  ('animal-person', -74),
#  ('create-build', -73),
#  ('motel-inn', -72),
#  ('hysteria-confusion', -71),
#  ('decide-choose', -70),
#  ('composer-writer', -70),
#  ('wine-liquor', -68),
#  ('journey-trip', -66),
#  ('air-helium', -66),
#  ('large-huge', -65),
#  ('weird-odd', -65),
#  ('delightful-cheerful', -64),
#  ('man-child', -64),
#  ('smart-intelligent', -63),
#  ('hard-difficult', -63),
#  ('borrow-beg', -63),
#  ('head-nail', -63),
#  ('essential-necessary', -61),
#  ('roof-ceiling', -59),
#  ('occur-happen', -58),
#  ('body-chest', -58),
#  ('hen-turkey', -56),
#  ('death-burial', -56),
#  ('organize-become', -56),
#  ('bird-hen', -54),
#  ('father-god', -52),
#  ('alley-bowl', -51),
#  ('cooperate-join', -49),
#  ('ignorance-intelligence', -49),
#  ('inform-notify', -48),
#  ('organ-liver', -46),
#  ('men-fraternity', -44),
#  ('keep-borrow', -44),
#  ('champion-winner', -42),
#  ('vehicle-bus', -42),
#  ('game-fun', -42),
#  ('explain-prove', -40),
#  ('book-topic', -40),
#  ('happy-young', -40),
#  ('game-trick', -38),
#  ('expand-grow', -35),
#  ('appoint-elect', -35),
#  ('arrange-organize', -33),
#  ('insane-crazy', -31),
#  ('crowd-parade', -30),
#  ('agony-grief', -28),
#  ('give-borrow', -28),
#  ('drizzle-rain', -27),
#  ('learn-evaluate', -26),
#  ('wood-paper', -25),
#  ('join-acquire', -25),
#  ('tin-aluminum', -23),
#  ('roam-wander', -22),
#  ('arm-body', -22),
#  ('diet-apple', -22),
#  ('rain-mist', -21),
#  ('era-decade', -20),
#  ('ball-cannon', -20),
#  ('bizarre-strange', -19),
#  ('root-grass', -19),
#  ('article-journal', -17),
#  ('band-orchestra', -16),
#  ('box-cigar', -16),
#  ('grass-blade', -15),
#  ('delightful-wonderful', -14),
#  ('oil-mink', -14),
#  ('celebration-ceremony', -13),
#  ('assume-predict', -13),
#  ('winner-candidate', -13),
#  ('business-industry', -11),
#  ('clarify-explain', -10),
#  ('advise-recommend', -10),
#  ('kill-choke', -10),
#  ('stupid-dumb', -8),
#  ('taxi-cab', -5),
#  ('happy-glad', -5),
#  ('strange-odd', -4),
#  ('strong-proud', -4),
#  ('vanish-disappear', -2),
#  ('pact-agreement', -2),
#  ('music-melody', -2),
#  ('long-narrow', -2),
#  ('friend-buddy', -1),
#  ('boat-deck', -1),
#  ('sheep-lamb', 0),
#  ('curve-angle', 0),
#  ('top-side', 2),
#  ('attorney-lawyer', 3),
#  ('jar-bottle', 5),
#  ('crucial-important', 6),
#  ('danger-threat', 6),
#  ('car-cab', 6),
#  ('winter-season', 6),
#  ('attitude-confidence', 6),
#  ('flower-violet', 7),
#  ('cup-cone', 9),
#  ('horse-mare', 11),
#  ('arm-bone', 11),
#  ('destroy-make', 11),
#  ('speak-acknowledge', 12),
#  ('inexpensive-cheap', 13),
#  ('withdraw-reject', 13),
#  ('woman-wife', 13),
#  ('box-hat', 14),
#  ('bar-cage', 16),
#  ('violin-instrument', 18),
#  ('leave-ignore', 18),
#  ('adult-baby', 18),
#  ('listen-hear', 19),
#  ('clothes-coat', 21),
#  ('school-law', 21),
#  ('anger-fury', 22),
#  ('achieve-accomplish', 24),
#  ('weird-strange', 25),
#  ('physician-doctor', 25),
#  ('keep-protect', 25),
#  ('letter-paragraph', 25),
#  ('victory-triumph', 26),
#  ('hard-tough', 26),
#  ('modest-flexible', 26),
#  ('steak-meat', 28),
#  ('beach-seashore', 30),
#  ('dreary-dull', 31),
#  ('understand-listen', 33),
#  ('apparent-obvious', 34),
#  ('argument-agreement', 34),
#  ('daughter-kid', 35),
#  ('old-new', 35),
#  ('movie-film', 38),
#  ('wonderful-terrific', 38),
#  ('captain-sailor', 39),
#  ('friend-teacher', 42),
#  ('make-become', 44),
#  ('hose-garden', 44),
#  ('sandwich-lunch', 46),
#  ('participate-join', 48),
#  ('honest-guilty', 48),
#  ('beach-sea', 49),
#  ('mud-dirt', 50),
#  ('forget-retain', 50),
#  ('whiskey-champagne', 51),
#  ('happiness-luck', 51),
#  ('kill-defend', 52),
#  ('nice-cruel', 53),
#  ('diet-salad', 54),
#  ('begin-quit', 55),
#  ('read-comprehend', 56),
#  ('investigate-examine', 57),
#  ('room-bath', 58),
#  ('nurse-scientist', 58),
#  ('despair-misery', 59),
#  ('rhythm-melody', 59),
#  ('worker-mechanic', 59),
#  ('wall-brick', 59),
#  ('get-remain', 59),
#  ('brother-soul', 59),
#  ('deliver-carry', 60),
#  ('fraternity-baseball', 62),
#  ('sly-tough', 62),
#  ('boy-brother', 63),
#  ('birthday-year', 63),
#  ('arrange-require', 66),
#  ('orthodontist-dentist', 67),
#  ('man-father', 67),
#  ('area-corner', 68),
#  ('lover-companion', 69),
#  ('bed-chair', 69),
#  ('accept-recommend', 69),
#  ('car-elevator', 69),
#  ('lake-swamp', 71),
#  ('sea-ocean', 73),
#  ('accept-acknowledge', 74),
#  ('car-highway', 74),
#  ('owe-lend', 74),
#  ('boy-kid', 76),
#  ('bird-turkey', 77),
#  ('river-sea', 77),
#  ('bad-terrible', 78),
#  ('clothes-cloth', 78),
#  ('body-stomach', 78),
#  ('sly-clever', 79),
#  ('gossip-news', 79),
#  ('book-bible', 79),
#  ('sick-crazy', 80),
#  ('night-dawn', 83),
#  ('strange-sly', 83),
#  ('cattle-beef', 85),
#  ('illness-infection', 85),
#  ('add-build', 85),
#  ('bath-trick', 85),
#  ('comprehend-satisfy', 86),
#  ('plane-jet', 88),
#  ('tower-bell', 88),
#  ('bath-wife', 88),
#  ('analyze-evaluate', 89),
#  ('sly-strange', 90),
#  ('cup-jar', 92),
#  ('wonderful-great', 95),
#  ('apple-sunshine', 95),
#  ('anarchy-chaos', 96),
#  ('rough-frigid', 96),
#  ('supper-meal', 98),
#  ('car-bridge', 98),
#  ('mink-fur', 99),
#  ('cent-size', 99),
#  ('carry-bring', 100),
#  ('bone-knee', 100),
#  ('learn-listen', 100),
#  ('huge-dumb', 101),
#  ('fresh-wide', 101),
#  ('hand-wrist', 102),
#  ('molecule-atom', 103),
#  ('determine-predict', 104),
#  ('moon-planet', 105),
#  ('sweater-jacket', 106),
#  ('destruction-construction', 106),
#  ('kidney-organ', 111),
#  ('hard-simple', 112),
#  ('metal-aluminum', 113),
#  ('princess-island', 114),
#  ('guy-girl', 115),
#  ('tobacco-cigarette', 116),
#  ('tin-metal', 118),
#  ('arm-muscle', 118),
#  ('college-profession', 118),
#  ('argue-justify', 120),
#  ('mountain-ledge', 121),
#  ('paper-cardboard', 122),
#  ('large-flexible', 122),
#  ('monster-demon', 123),
#  ('hymn-conquest', 123),
#  ('bicycle-bedroom', 124),
#  ('apple-sauce', 125),
#  ('canyon-valley', 126),
#  ('toe-finger', 126),
#  ('pretend-seem', 126),
#  ('bottom-side', 126),
#  ('bean-coffee', 128),
#  ('condition-boy', 128),
#  ('new-ancient', 128),
#  ('understand-know', 131),
#  ('ballad-song', 134),
#  ('disappear-shrink', 134),
#  ('cliff-tail', 134),
#  ('elegance-style', 135),
#  ('horn-drum', 135),
#  ('worker-employer', 136),
#  ('bone-elbow', 137),
#  ('dinner-soup', 137),
#  ('house-carpet', 141),
#  ('insect-bee', 143),
#  ('fee-salary', 143),
#  ('polyester-cotton', 144),
#  ('beach-island', 144),
#  ('take-carry', 144),
#  ('door-floor', 144),
#  ('door-cellar', 146),
#  ('dumb-foolish', 147),
#  ('date-calendar', 147),
#  ('meat-bacon', 148),
#  ('breakfast-bacon', 148),
#  ('motor-boat', 148),
#  ('multiply-divide', 148),
#  ('meal-dinner', 149),
#  ('disease-infection', 149),
#  ('become-seem', 149),
#  ('bone-ankle', 150),
#  ('beg-ask', 152),
#  ('word-clue', 154),
#  ('horse-colt', 159),
#  ('sorrow-shame', 159),
#  ('ignore-explore', 159),
#  ('boy-son', 160),
#  ('navy-army', 160),
#  ('man-uncle', 160),
#  ('clothes-jacket', 161),
#  ('find-disappear', 161),
#  ('street-car', 163),
#  ('oak-maple', 165),
#  ('leave-wander', 166),
#  ('hip-lip', 167),
#  ('door-gate', 169),
#  ('accept-deliver', 170),
#  ('give-allow', 171),
#  ('friend-guy', 173),
#  ('dinner-chicken', 173),
#  ('ask-pray', 176),
#  ('snow-weather', 178),
#  ('snow-storm', 178),
#  ('accept-forgive', 178),
#  ('hand-thumb', 181),
#  ('leave-appear', 184),
#  ('multiply-add', 187),
#  ('doctor-orthodontist', 188),
#  ('science-psychology', 188),
#  ('bone-teeth', 189),
#  ('do-quit', 189),
#  ('school-grade', 190),
#  ('bowl-tail', 190),
#  ('cheek-tongue', 192),
#  ('flower-bulb', 192),
#  ('whiskey-gin', 193),
#  ('send-attend', 193),
#  ('go-sell', 194),
#  ('lemon-tea', 196),
#  ('restless-young', 197),
#  ('actress-actor', 199),
#  ('sugar-honey', 201),
#  ('world-globe', 203),
#  ('priest-monk', 204),
#  ('afraid-anxious', 204),
#  ('go-enter', 206),
#  ('heart-surgery', 206),
#  ('neck-spine', 208),
#  ('kill-destroy', 212),
#  ('impatient-anxious', 213),
#  ('childish-foolish', 213),
#  ('apartment-furniture', 213),
#  ('archbishop-bishop', 216),
#  ('beautiful-wonderful', 217),
#  ('car-hose', 218),
#  ('nerve-brain', 222),
#  ('roof-floor', 222),
#  ('anatomy-biology', 224),
#  ('bed-blanket', 224),
#  ('easy-big', 224),
#  ('prince-king', 226),
#  ('cab-bus', 226),
#  ('arm-knee', 226),
#  ('author-reader', 226),
#  ('weird-normal', 227),
#  ('child-boy', 228),
#  ('lose-keep', 235),
#  ('frustration-anger', 236),
#  ('want-choose', 237),
#  ('sad-terrible', 238),
#  ('clothes-closet', 238),
#  ('terrific-mad', 238),
#  ('forgive-forget', 240),
#  ('different-normal', 240),
#  ('house-barn', 242),
#  ('breathe-choke', 244),
#  ('grass-moss', 245),
#  ('storm-hurricane', 247),
#  ('horse-ox', 247),
#  ('beer-champagne', 249),
#  ('know-believe', 250),
#  ('bring-restore', 251),
#  ('ignore-ask', 251),
#  ('joy-pride', 254),
#  ('mad-glad', 256),
#  ('hill-cliff', 259),
#  ('guitar-drum', 259),
#  ('door-doorway', 261),
#  ('bone-neck', 261),
#  ('beer-beverage', 263),
#  ('word-dictionary', 263),
#  ('bacon-bean', 264),
#  ('go-send', 267),
#  ('dentist-colonel', 271),
#  ('girl-child', 272),
#  ('assume-pretend', 272),
#  ('cat-pet', 275),
#  ('give-know', 275),
#  ('difficult-simple', 275),
#  ('house-apartment', 276),
#  ('street-alley', 277),
#  ('arm-shoulder', 278),
#  ('wealth-poverty', 284),
#  ('sharp-dull', 284),
#  ('argue-prove', 286),
#  ('apple-lemon', 287),
#  ('disorganize-organize', 290),
#  ('finger-palm', 291),
#  ('complain-argue', 293),
#  ('give-put', 300),
#  ('denial-confession', 302),
#  ('book-essay', 304),
#  ('baby-daughter', 307),
#  ('wine-brandy', 310),
#  ('door-kitchen', 310),
#  ('give-deny', 310),
#  ('reality-illusion', 310),
#  ('tongue-throat', 312),
#  ('destroy-construct', 312),
#  ('page-paragraph', 314),
#  ('dirty-cheap', 315),
#  ('illegal-immoral', 321),
#  ('reality-fantasy', 322),
#  ('agree-differ', 324),
#  ('phrase-word', 325),
#  ('hound-fox', 328),
#  ('try-think', 329),
#  ('chocolate-pie', 329),
#  ('ball-basket', 329),
#  ('logic-arithmetic', 334),
#  ('apple-candy', 337),
#  ('steal-buy', 340),
#  ('milk-juice', 342),
#  ('hat-coat', 343),
#  ('give-steal', 343),
#  ('happy-angry', 344),
#  ('take-leave', 352),
#  ('boat-car', 352),
#  ('day-morning', 354),
#  ('actor-singer', 354),
#  ('apple-juice', 355),
#  ('lens-camera', 358),
#  ('cereal-wheat', 358),
#  ('succeed-fail', 358),
#  ('muscle-bone', 360),
#  ('uncle-aunt', 361),
#  ('nose-mouth', 361),
#  ('bone-jaw', 362),
#  ('meat-sandwich', 363),
#  ('trial-verdict', 364),
#  ('girl-maid', 366),
#  ('accept-deny', 366),
#  ('basketball-baseball', 376),
#  ('forget-learn', 376),
#  ('beach-reef', 378),
#  ('do-happen', 380),
#  ('arm-wrist', 381),
#  ('lawyer-banker', 383),
#  ('keep-give', 383),
#  ('child-adult', 384),
#  ('student-professor', 384),
#  ('water-salt', 389),
#  ('blood-marrow', 395),
#  ('borrow-sell', 404),
#  ('apartment-hotel', 405),
#  ('chicken-steak', 412),
#  ('lady-gentleman', 414),
#  ('plane-airport', 416),
#  ('bring-send', 418),
#  ('boy-soldier', 420),
#  ('sun-sky', 422),
#  ('leave-remain', 426),
#  ('happy-mad', 426),
#  ('put-hang', 427),
#  ('speak-hear', 429),
#  ('sheep-cattle', 432),
#  ('butter-potato', 432),
#  ('tiny-huge', 433),
#  ('create-destroy', 434),
#  ('breakfast-supper', 438),
#  ('bad-terrific', 440),
#  ('king-princess', 441),
#  ('bed-bedroom', 443),
#  ('gun-knife', 444),
#  ('floor-ceiling', 445),
#  ('bee-ant', 446),
#  ('meat-bread', 448),
#  ('car-bicycle', 451),
#  ('spend-save', 453),
#  ('ball-glove', 454),
#  ('forget-ignore', 456),
#  ('absence-presence', 456),
#  ('get-put', 473),
#  ('dog-horse', 478),
#  ('salad-vinegar', 481),
#  ('cousin-uncle', 486),
#  ('church-choir', 486),
#  ('dumb-intelligent', 486),
#  ('spoon-cup', 489),
#  ('great-awful', 489),
#  ('throat-nose', 491),
#  ('room-bed', 494),
#  ('biography-fiction', 500),
#  ('bride-princess', 503),
#  ('god-devil', 504),
#  ('bed-couch', 505),
#  ('decade-century', 510),
#  ('classroom-hallway', 517),
#  ('bad-great', 517),
#  ('weekend-week', 519),
#  ('father-brother', 524),
#  ('employer-employee', 526),
#  ('leg-arm', 529),
#  ('bathroom-bedroom', 531),
#  ('bread-flour', 532),
#  ('arm-neck', 535),
#  ('narrow-broad', 540),
#  ('chicken-rice', 541),
#  ('window-door', 543),
#  ('dad-mother', 546),
#  ('arrive-leave', 547),
#  ('unnecessary-necessary', 547),
#  ('rice-bean', 549),
#  ('lose-get', 557),
#  ('friend-mother', 565),
#  ('wide-narrow', 565),
#  ('bed-hospital', 566),
#  ('send-receive', 567),
#  ('mouse-cat', 568),
#  ('dull-funny', 568),
#  ('night-day', 572),
#  ('son-father', 573),
#  ('dumb-clever', 582),
#  ('aunt-nephew', 587),
#  ('bathroom-kitchen', 590),
#  ('groom-bride', 595),
#  ('river-valley', 597),
#  ('dinner-breakfast', 599),
#  ('cow-goat', 602),
#  ('hard-easy', 605),
#  ('bottom-top', 605),
#  ('north-west', 606),
#  ('leave-enter', 616),
#  ('bread-cheese', 617),
#  ('tax-income', 618),
#  ('sinner-saint', 618),
#  ('receive-give', 619),
#  ('brother-son', 620),
#  ('elbow-ankle', 620),
#  ('liver-lung', 623),
#  ('easy-tough', 623),
#  ('woman-man', 624),
#  ('sad-funny', 637),
#  ('come-bring', 646),
#  ('mother-wife', 653),
#  ('cat-rabbit', 655),
#  ('modern-ancient', 662),
#  ('sunset-sunrise', 667),
#  ('go-come', 668),
#  ('agree-argue', 682),
#  ('father-daughter', 688),
#  ('winter-summer', 710),
#  ('short-long', 716),
#  ('encourage-discourage', 727),
#  ('remind-forget', 749),
#  ('wife-husband', 755),
#  ('forget-know', 767),
#  ('south-north', 770),
#  ('dog-cat', 781),
#  ('smart-dumb', 808),
#  ('easy-difficult', 814),
#  ('accept-reject', 845),
#  ('shrink-grow', 852)]
